# %% [markdown]
# Tässä melkein tyhjä Jupyter Notebook-tiedosto jota voit käyttää harjoitteluun.
#
# Pikaohje:
#
#   ![image-2.png](attachment:image-2.png)

# %%
# Tässä on koodisolu ja risuaidalla aloitetaan kommenttirivi

import matplotlib.pyplot as plt # Avataan matikkakirjasto ja nimetään se plt:ksi
import pandas as pd # Avataan IO-kirjasto ja nimetään se pd:ksi
import numpy as np # Avataan tieteellisen laskennan kirjasto

# Nyt voit käyttää kirjastoja, esim. laskea sin(2):n arvo ja tulostaa sen
# Huom! Kun käytät kirjastoja niin alkuun pitää laittaa kirjaston nimi ja piste, sitten vasta
# ko. kirjaston komento

print(np.sin(2))
# Out:
# 0.9092974268256817
